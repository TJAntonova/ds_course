# %% [markdown]
# # Исследование надежности заемщиков.

# %% [markdown]
# ## Обзор данных

# %%
import pandas as pd
data = pd.read_csv('\datasets\data.csv')
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1   -8437.673028         42    высшее             0
# 1             1   -4024.803754         36   среднее             1
# 2             0   -5623.422610         33   Среднее             1
# 3             3   -4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1   -4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1   -2113.346888         38   среднее             1
# 21523         3   -3112.481705         38   среднее             1
# 21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля
#
# [21525 rows x 12 columns]

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Пропуски значений

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# В столбцах `days_employed` и `total_income` обнаружены пропуски, которые составляют 10% от количества строк. Скорее всего, данные по случайности не были внесены составителями изначально. В наших данных могут быть значения, которые сильно выделяются среди большинства, поэтому заполнять пропуски средним будет некорректно. Заполним их медианным значением.

# %%
sorted_days_employed = data.sort_values(by='days_employed')
days_emp_median = sorted_days_employed['days_employed'].median()
# медиана по общему трудовому стажу

# %%
sorted_total_income = data.sort_values(by='total_income')
total_inc_median = sorted_total_income ['total_income'].median()
# медиана ежемесячного дохода

# %%
data['days_employed'] = data['days_employed'].fillna(days_emp_median)
data['total_income'] = data['total_income'].fillna(total_inc_median)
# заполнение пропусков

# %%
data.isna().sum() # проверка
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Проверка данных на аномалии и исправления

# %%
columns = data.columns
for c in columns:
    print(c.upper(), '\n', data[c].unique(), '\n')
# вывод уникальных значений в столбцах для проверки данных
# Out:
# CHILDREN
#  [ 1  0  3  2 -1  4 20  5]
#
# DAYS_EMPLOYED
#  [-8437.67302776 -4024.80375385 -5623.42261023 ... -2113.3468877
#  -3112.4817052  -1984.50758853]
#
# DOB_YEARS
#  [42 36 33 32 53 27 43 50 35 41 40 65 54 56 26 48 24 21 57 67 28 63 62 47
#  34 68 25 31 30 20 49 37 45 61 64 44 52 46 23 38 39 51  0 59 29 60 55 58
#  71 22 73 66 69 19 72 70 74 75]
#
# EDUCATION
#  ['высшее' 'среднее' 'Среднее' 'СРЕДНЕЕ' 'ВЫСШЕЕ' 'неоконченное высшее'
#  'начальное' 'Высшее' 'НЕОКОНЧЕННОЕ ВЫСШЕЕ' 'Неоконченное высшее'
#  'НАЧАЛЬНОЕ' 'Начальное' 'Ученая степень' 'УЧЕНАЯ СТЕПЕНЬ'
#  'ученая степень']
#
# EDUCATION_ID
#  [0 1 2 3 4]
#
# FAMILY_STATUS
#  ['женат / замужем' 'гражданский брак' 'вдовец / вдова' 'в разводе'
#  'Не женат / не замужем']
#
# FAMILY_STATUS_ID
#  [0 1 2 3 4]
#
# GENDER
#  ['F' 'M' 'XNA']
#
# INCOME_TYPE
#  ['сотрудник' 'пенсионер' 'компаньон' 'госслужащий' 'безработный'
#  'предприниматель' 'студент' 'в декрете']
#
# DEBT
#  [0 1]
#
# TOTAL_INCOME
#  [253875.6394526  112080.01410244 145885.95229686 ...  89672.56115303
#  244093.05050043  82047.41889948]
#
# PURPOSE
#  ['покупка жилья' 'приобретение автомобиля' 'дополнительное образование'
#  'сыграть свадьбу' 'операции с жильем' 'образование'
#  'на проведение свадьбы' 'покупка жилья для семьи' 'покупка недвижимости'
#  'покупка коммерческой недвижимости' 'покупка жилой недвижимости'
#  'строительство собственной недвижимости' 'недвижимость'
#  'строительство недвижимости' 'на покупку подержанного автомобиля'
#  'на покупку своего автомобиля' 'операции с коммерческой недвижимостью'
#  'строительство жилой недвижимости' 'жилье'
#  'операции со своей недвижимостью' 'автомобили' 'заняться образованием'
#  'сделка с подержанным автомобилем' 'получение образования' 'автомобиль'
#  'свадьба' 'получение дополнительного образования' 'покупка своего жилья'
#  'операции с недвижимостью' 'получение высшего образования'
#  'свой автомобиль' 'сделка с автомобилем' 'профильное образование'
#  'высшее образование' 'покупка жилья для сдачи' 'на покупку автомобиля'
#  'ремонт жилью' 'заняться высшим образованием']

# %% [markdown]
# Видим несколько проблем:
# 1. в столбце `children` значения -1 и 20;
# 2. в стоблце `days_employed` отрицательные значения;
# 3. в столбце `dob_years` значение 0;
# 4. в столбце `education` дубликаты;
# 5. столбцы `purpose` и `total_income` следует для удобства разбить на категории.
#
# Сначала исправим аномалии.

# %%
data.loc[data['children'] == 20]
# Out:
#        children  days_employed  dob_years education  education_id  \
# 606          20    -880.221113         21   среднее             1
# 720          20    -855.595512         44   среднее             1
# 1074         20   -3310.411598         56   среднее             1
# 2510         20   -2714.161249         59    высшее             0
# 2941         20   -2161.591519          0   среднее             1
# ...         ...            ...        ...       ...           ...
# 21008        20   -1240.257910         40   среднее             1
# 21325        20    -601.174883         37   среднее             1
# 21390        20   -1203.369529         53   среднее             1
# 21404        20    -494.788448         52   среднее             1
# 21491        20    -173.954460         27   среднее             1
#
#          family_status  family_status_id gender income_type  debt  \
# 606    женат / замужем                 0      M   компаньон     0
# 720    женат / замужем                 0      F   компаньон     0
# 1074   женат / замужем                 0      F   сотрудник     1
# 2510    вдовец / вдова                 2      F   сотрудник     0
# 2941   женат / замужем                 0      F   сотрудник     0
# ...                ...               ...    ...         ...   ...
# 21008  женат / замужем                 0      F   сотрудник     1
# 21325  женат / замужем                 0      F   компаньон     0
# 21390  женат / замужем                 0      M   компаньон     0
# 21404  женат / замужем                 0      M   компаньон     0
# 21491  женат / замужем                 0      F   сотрудник     0
#
#         total_income                                purpose
# 606    145334.865002                          покупка жилья
# 720    112998.738649                   покупка недвижимости
# 1074   229518.537004                  получение образования
# 2510   264474.835577  операции с коммерческой недвижимостью
# 2941   199739.941398                  на покупку автомобиля
# ...              ...                                    ...
# 21008  133524.010303                        свой автомобиль
# 21325  102986.065978                 профильное образование
# 21390  145017.937533             покупка жилой недвижимости
# 21404  156629.683642        операции со своей недвижимостью
# 21491  155520.899688     на покупку подержанного автомобиля
#
# [76 rows x 12 columns]

# %% [markdown]
# По статистике в России 23 750 000 семей с детьми, из которых в 943 более 11 детей. Я бы уточнила, ошибка в нашей выборке или нет. Пока примем за ошибку (в 21 год вероятность иметь столько детей очень мала) и уберем ноль.

# %%
data.loc[(data.children == 20), 'children'] = 2
data.loc[(data.children == -1), 'children'] = 1
# исправляем значения

# %%
data['days_employed'] = abs(data['days_employed'])
# убираем отрицательные значения в стаже работы

# %%
sorted_age = data.sort_values(by='dob_years')
age_median = sorted_age ['dob_years'].median()
data.loc[(data.dob_years == 0), 'dob_years'] = int(age_median)
# заполняем значение 0 в возрасте клиента медианным значением по выборке

# %% [markdown]
# ### Удаление дубликатов

# %%
data.duplicated().sum()
# подсчёт явных дубликатов
print(f"Кол-во явных дубликатов:{data.duplicated().sum()}")
# Out:
# Кол-во явных дубликатов:55

# %%
data = data.drop_duplicates().reset_index(drop=True) 
# удаление явных дубликатов (с удалением старых индексов и формированием новых)
print(f"Кол-во явных дубликатов:{data.duplicated().sum()}") # проверка на отсутствие явных дубликатов
# Out:
# Кол-во явных дубликатов:0

# %%
data['education'] = data['education'].str.lower()
# обработка неявных дубликатов в столбце образование
data['education'].unique()
# Out:
# array(['высшее', 'среднее', 'неоконченное высшее', 'начальное',
#        'ученая степень'], dtype=object)

# %% [markdown]
# ### Категоризация целей кредита

# %% [markdown]
# Лучше всего токенизировать и лемматизировать строки, чтобы именно по леммам категоризировать цели кредита.

# %%
import pip
pip.main(['install', 'pymorphy2'])
import pymorphy2
morph = pymorphy2.MorphAnalyzer()
# импортируем пайморфи
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: pymorphy2 in c:\users\js\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: docopt>=0.6 in c:\users\js\anaconda3\lib\site-packages (from pymorphy2) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\js\anaconda3\lib\site-packages (from pymorphy2) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\js\anaconda3\lib\site-packages (from pymorphy2) (2.4.417127.4579844)
# Loading dictionaries from C:\Users\js\anaconda3\lib\site-packages\pymorphy2_dicts_ru\data
# format: 2.4, revision: 417127, updated: 2020-10-11T15:05:51.070345

# %%
def purpose_column(purpose):
    
    '''функция принимает на вход цели кредита, 
    токенизирует, лемматизирует,
    по лемме категоризирует данные'''
    
    for w in purpose.split():
        w = morph.parse(w)[0].normal_form
        if w == 'образование':
            return 'получение образования'
        if w == 'автомобиль':
            return 'операции с автомобилем'
        if w == 'свадьба':
            return 'проведение свадьбы'
    return 'операции с недвижимостью'

data['purpose_category'] = data['purpose'].apply(purpose_column) # применяем функцию к датафрейму и создаем столбец

# %%
data.head(20) # проверка
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1    8437.673028         42               высшее             0
# 1          1    4024.803754         36              среднее             1
# 2          0    5623.422610         33              среднее             1
# 3          3    4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0     926.185831         27               высшее             0
# 6          0    2879.202052         43               высшее             0
# 7          0     152.779569         50              среднее             1
# 8          2    6929.865299         35               высшее             0
# 9          0    2188.756445         41              среднее             1
# 10         2    4171.483647         36               высшее             0
# 11         0     792.701887         40              среднее             1
# 12         0    1203.369529         65              среднее             1
# 13         0    1846.641941         54  неоконченное высшее             2
# 14         0    1844.956182         56               высшее             0
# 15         1     972.364419         26              среднее             1
# 16         0    1719.934226         35              среднее             1
# 17         0    2369.999720         33               высшее             0
# 18         0  400281.136913         53              среднее             1
# 19         0   10038.818549         48              среднее             1
#
#        family_status  family_status_id gender income_type  debt  \
# 0    женат / замужем                 0      F   сотрудник     0
# 1    женат / замужем                 0      F   сотрудник     0
# 2    женат / замужем                 0      M   сотрудник     0
# 3    женат / замужем                 0      M   сотрудник     0
# 4   гражданский брак                 1      F   пенсионер     0
# 5   гражданский брак                 1      M   компаньон     0
# 6    женат / замужем                 0      F   компаньон     0
# 7    женат / замужем                 0      M   сотрудник     0
# 8   гражданский брак                 1      F   сотрудник     0
# 9    женат / замужем                 0      M   сотрудник     0
# 10   женат / замужем                 0      M   компаньон     0
# 11   женат / замужем                 0      F   сотрудник     0
# 12  гражданский брак                 1      M   пенсионер     0
# 13   женат / замужем                 0      F   сотрудник     0
# 14  гражданский брак                 1      F   компаньон     1
# 15   женат / замужем                 0      F   сотрудник     0
# 16   женат / замужем                 0      F   сотрудник     0
# 17  гражданский брак                 1      M   сотрудник     0
# 18    вдовец / вдова                 2      F   пенсионер     0
# 19         в разводе                 3      F   сотрудник     0
#
#      total_income                                 purpose  \
# 0   253875.639453                           покупка жилья
# 1   112080.014102                 приобретение автомобиля
# 2   145885.952297                           покупка жилья
# 3   267628.550329              дополнительное образование
# 4   158616.077870                         сыграть свадьбу
# 5   255763.565419                           покупка жилья
# 6   240525.971920                       операции с жильем
# 7   135823.934197                             образование
# 8    95856.832424                   на проведение свадьбы
# 9   144425.938277                 покупка жилья для семьи
# 10  113943.491460                    покупка недвижимости
# 11   77069.234271       покупка коммерческой недвижимости
# 12  145017.937533                         сыграть свадьбу
# 13  130458.228857                 приобретение автомобиля
# 14  165127.911772              покупка жилой недвижимости
# 15  116820.904450  строительство собственной недвижимости
# 16  289202.704229                            недвижимость
# 17   90410.586745              строительство недвижимости
# 18   56823.777243      на покупку подержанного автомобиля
# 19  242831.107982            на покупку своего автомобиля
#
#             purpose_category
# 0   операции с недвижимостью
# 1     операции с автомобилем
# 2   операции с недвижимостью
# 3      получение образования
# 4         проведение свадьбы
# 5   операции с недвижимостью
# 6   операции с недвижимостью
# 7      получение образования
# 8         проведение свадьбы
# 9   операции с недвижимостью
# 10  операции с недвижимостью
# 11  операции с недвижимостью
# 12        проведение свадьбы
# 13    операции с автомобилем
# 14  операции с недвижимостью
# 15  операции с недвижимостью
# 16  операции с недвижимостью
# 17  операции с недвижимостью
# 18    операции с автомобилем
# 19    операции с автомобилем

# %% [markdown]
# ### Изменение типов данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21470 entries, 0 to 21469
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21470 non-null  int64
#  1   days_employed     21470 non-null  float64
#  2   dob_years         21470 non-null  int64
#  3   education         21470 non-null  object
#  4   education_id      21470 non-null  int64
#  5   family_status     21470 non-null  object
#  6   family_status_id  21470 non-null  int64
#  7   gender            21470 non-null  object
#  8   income_type       21470 non-null  object
#  9   debt              21470 non-null  int64
#  10  total_income      21470 non-null  float64
#  11  purpose           21470 non-null  object
#  12  purpose_category  21470 non-null  object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# Тип `float` в ежемесячном доходе затруднит дальнейшую работу, преобразуем его в `int`.

# %%
data['total_income'] = data['total_income'].astype('int')
data.info() # проверяем
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21470 entries, 0 to 21469
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21470 non-null  int64
#  1   days_employed     21470 non-null  float64
#  2   dob_years         21470 non-null  int64
#  3   education         21470 non-null  object
#  4   education_id      21470 non-null  int64
#  5   family_status     21470 non-null  object
#  6   family_status_id  21470 non-null  int64
#  7   gender            21470 non-null  object
#  8   income_type       21470 non-null  object
#  9   debt              21470 non-null  int64
#  10  total_income      21470 non-null  int32
#  11  purpose           21470 non-null  object
#  12  purpose_category  21470 non-null  object
# dtypes: float64(1), int32(1), int64(5), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Категоризация дохода

# %%
def income_column(income):
    
    '''функция создает столбец с категориями доходов на основании диапозонов'''
    
    if income <= 30000:
        return 'E'
    if income <= 50000:
        return 'D'
    if income <= 200000:
        return 'C'
    if income <= 1000000:
        return 'B'
    return 'A'

data['total_income_category'] = data['total_income'].apply(income_column)  # применяем функцию к датафрейму и создаем столбец

# %%
data.head(20) # проверка
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1    8437.673028         42               высшее             0
# 1          1    4024.803754         36              среднее             1
# 2          0    5623.422610         33              среднее             1
# 3          3    4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0     926.185831         27               высшее             0
# 6          0    2879.202052         43               высшее             0
# 7          0     152.779569         50              среднее             1
# 8          2    6929.865299         35               высшее             0
# 9          0    2188.756445         41              среднее             1
# 10         2    4171.483647         36               высшее             0
# 11         0     792.701887         40              среднее             1
# 12         0    1203.369529         65              среднее             1
# 13         0    1846.641941         54  неоконченное высшее             2
# 14         0    1844.956182         56               высшее             0
# 15         1     972.364419         26              среднее             1
# 16         0    1719.934226         35              среднее             1
# 17         0    2369.999720         33               высшее             0
# 18         0  400281.136913         53              среднее             1
# 19         0   10038.818549         48              среднее             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0    женат / замужем                 0      F   сотрудник     0        253875
# 1    женат / замужем                 0      F   сотрудник     0        112080
# 2    женат / замужем                 0      M   сотрудник     0        145885
# 3    женат / замужем                 0      M   сотрудник     0        267628
# 4   гражданский брак                 1      F   пенсионер     0        158616
# 5   гражданский брак                 1      M   компаньон     0        255763
# 6    женат / замужем                 0      F   компаньон     0        240525
# 7    женат / замужем                 0      M   сотрудник     0        135823
# 8   гражданский брак                 1      F   сотрудник     0         95856
# 9    женат / замужем                 0      M   сотрудник     0        144425
# 10   женат / замужем                 0      M   компаньон     0        113943
# 11   женат / замужем                 0      F   сотрудник     0         77069
# 12  гражданский брак                 1      M   пенсионер     0        145017
# 13   женат / замужем                 0      F   сотрудник     0        130458
# 14  гражданский брак                 1      F   компаньон     1        165127
# 15   женат / замужем                 0      F   сотрудник     0        116820
# 16   женат / замужем                 0      F   сотрудник     0        289202
# 17  гражданский брак                 1      M   сотрудник     0         90410
# 18    вдовец / вдова                 2      F   пенсионер     0         56823
# 19         в разводе                 3      F   сотрудник     0        242831
#
#                                    purpose          purpose_category  \
# 0                            покупка жилья  операции с недвижимостью
# 1                  приобретение автомобиля    операции с автомобилем
# 2                            покупка жилья  операции с недвижимостью
# 3               дополнительное образование     получение образования
# 4                          сыграть свадьбу        проведение свадьбы
# 5                            покупка жилья  операции с недвижимостью
# 6                        операции с жильем  операции с недвижимостью
# 7                              образование     получение образования
# 8                    на проведение свадьбы        проведение свадьбы
# 9                  покупка жилья для семьи  операции с недвижимостью
# 10                    покупка недвижимости  операции с недвижимостью
# 11       покупка коммерческой недвижимости  операции с недвижимостью
# 12                         сыграть свадьбу        проведение свадьбы
# 13                 приобретение автомобиля    операции с автомобилем
# 14              покупка жилой недвижимости  операции с недвижимостью
# 15  строительство собственной недвижимости  операции с недвижимостью
# 16                            недвижимость  операции с недвижимостью
# 17              строительство недвижимости  операции с недвижимостью
# 18      на покупку подержанного автомобиля    операции с автомобилем
# 19            на покупку своего автомобиля    операции с автомобилем
#
#    total_income_category
# 0                      B
# 1                      C
# 2                      C
# 3                      B
# 4                      C
# 5                      B
# 6                      B
# 7                      C
# 8                      C
# 9                      C
# 10                     C
# 11                     C
# 12                     C
# 13                     C
# 14                     C
# 15                     C
# 16                     B
# 17                     C
# 18                     C
# 19                     B

# %% [markdown]
# ### Формирование дополнительных датафреймов словарей, декомпозиция исходного датафрейма

# %%
education_dict = data[['education', 'education_id']]
family_status_dict = data[['family_status','family_status_id']]
# создание словарей для дальнейшего обращения по идентификатору

# %%
data.drop(columns = ['education', 'family_status', 'total_income', 'purpose'],axis = 1, inplace=True)
# удаление 'лишних' столбцов

# %%
pd.options.display.max_rows = 22000 
data.head(200) # смотрим на итоговый датафрейм
# Out:
#      children  days_employed  dob_years  education_id  family_status_id  \
# 0           1    8437.673028         42             0                 0
# 1           1    4024.803754         36             1                 0
# 2           0    5623.422610         33             1                 0
# 3           3    4124.747207         32             1                 0
# 4           0  340266.072047         53             1                 1
# 5           0     926.185831         27             0                 1
# 6           0    2879.202052         43             0                 0
# 7           0     152.779569         50             1                 0
# 8           2    6929.865299         35             0                 1
# 9           0    2188.756445         41             1                 0
# 10          2    4171.483647         36             0                 0
# 11          0     792.701887         40             1                 0
# 12          0    1203.369529         65             1                 1
# 13          0    1846.641941         54             2                 0
# 14          0    1844.956182         56             0                 1
# 15          1     972.364419         26             1                 0
# 16          0    1719.934226         35             1                 0
# 17          0    2369.999720         33             0                 1
# 18          0  400281.136913         53             1                 2
# 19          0   10038.818549         48             1                 3
# 20          1    1311.604166         36             1                 0
# 21          1     253.685166         33             1                 1
# 22          1    1766.644138         24             1                 1
# 23          0     272.981385         21             0                 1
# 24          1  338551.952911         57             1                 4
# 25          0  363548.489348         67             1                 0
# 26          0    1203.369529         41             1                 0
# 27          0     529.191635         28             0                 0
# 28          1     717.274324         26             0                 0
# 29          0    1203.369529         63             1                 4
# 30          1  335581.668515         62             1                 0
# 31          0    1682.083438         47             3                 0
# 32          0    4649.910832         34             1                 1
# 33          0    1548.637544         48             1                 0
# 34          0    4488.067031         35             1                 0
# 35          0  394021.072184         68             1                 1
# 36          0     176.216688         33             1                 4
# 37          0    6448.810860         43             0                 1
# 38          0     597.881827         25             0                 4
# 39          0     650.587796         31             0                 1
# 40          0    1030.362606         30             1                 4
# 41          0    1203.369529         50             1                 0
# 42          0    1257.496190         20             2                 4
# 43          0    4375.681384         43             2                 3
# 44          1    1362.041728         26             1                 0
# 45          1    1039.451741         49             1                 4
# 46          2    2262.712304         37             1                 0
# 47          1    2689.137274         33             0                 1
# 48          0    3341.067886         45             1                 0
# 49          0    1181.443228         54             1                 0
# 50          0  353731.432338         63             1                 0
# 51          1    6953.631655         50             0                 1
# 52          1    3554.671526         28             1                 0
# 53          0    4219.883386         61             1                 3
# 54          0    3480.072793         27             0                 1
# 55          0    1203.369529         54             1                 1
# 56          0  370145.087237         64             1                 2
# 57          0    2424.809749         44             1                 2
# 58          0     335.318630         36             0                 0
# 59          0    4341.786775         53             1                 1
# 60          1    2534.462390         48             1                 0
# 61          0    2986.202120         42             1                 1
# 62          0    7845.649233         48             0                 4
# 63          0    1182.547744         45             1                 0
# 64          0     118.891411         35             2                 4
# 65          0    1203.369529         21             1                 4
# 66          0     916.428829         28             1                 0
# 67          0    1203.369529         52             0                 0
# 68          2    2152.475526         46             0                 0
# 69          0     779.228449         23             1                 4
# 70          1    2802.226671         28             0                 0
# 71          0  338113.529892         62             1                 0
# 72          1    1203.369529         32             0                 0
# 73          0    1631.939403         40             1                 1
# 74          1    5110.543709         45             1                 0
# 75          1    2953.151948         38             1                 0
# 76          1    2252.192722         44             0                 0
# 77          0     726.943771         43             0                 4
# 78          0  359722.945074         61             0                 0
# 79          0    3278.296751         27             1                 4
# 80          0     127.334942         25             1                 4
# 81          0     204.673166         33             1                 0
# 82          2    1203.369529         50             0                 0
# 83          0    1203.369529         52             1                 0
# 84          0    7125.215028         53             1                 0
# 85          0     275.993847         30             1                 0
# 86          0  383933.549664         64             1                 1
# 87          0  337659.535004         53             1                 0
# 88          0  373129.789654         63             0                 1
# 89          0      72.625785         42             1                 1
# 90          2    1203.369529         35             0                 0
# 91          2    5010.997436         39             1                 0
# 92          1    1669.279681         40             0                 1
# 93          1    1446.622542         32             1                 0
# 94          1    1203.369529         34             0                 1
# 95          0     541.832241         51             0                 0
# 96          0    1203.369529         44             1                 0
# 97          0    1203.369529         47             0                 0
# 98          0  364906.205736         54             0                 0
# 99          0  346541.618895         42             1                 0
# 100         0     605.026441         49             1                 2
# 101         0  391558.961849         65             1                 0
# 102         0    1377.447235         51             1                 1
# 103         1     888.283347         39             1                 4
# 104         0  366323.649429         59             1                 4
# 105         0    2098.626296         62             1                 2
# 106         1     300.642593         29             1                 1
# 107         0    1493.449117         24             0                 1
# 108         2     753.467042         33             0                 1
# 109         0    2147.472608         59             1                 0
# 110         0     413.982602         41             1                 0
# 111         0   12930.541678         61             1                 4
# 112         1    1841.358094         28             0                 0
# 113         0    6083.994730         52             1                 0
# 114         0    1599.879161         26             0                 0
# 115         1    2523.847898         38             0                 0
# 116         1     540.038425         50             1                 0
# 117         0    3817.113295         41             1                 3
# 118         2    2774.655137         33             1                 1
# 119         0  382189.129056         60             1                 4
# 120         0    1203.369529         46             1                 0
# 121         0    1203.369529         29             0                 0
# 122         0     171.162421         55             0                 0
# 123         2    5718.708901         39             1                 0
# 124         0    1080.514782         38             1                 0
# 125         0     191.146746         64             0                 1
# 126         1    2471.548552         49             1                 0
# 127         0    5229.552069         43             0                 4
# 128         0  379035.920619         67             1                 3
# 129         0  361010.321350         61             1                 1
# 130         0     897.322806         42             1                 0
# 131         0     639.564708         58             1                 0
# 132         1    1306.428456         45             1                 0
# 133         0  344507.392785         64             1                 0
# 134         1    4171.107677         46             2                 3
# 135         0    1203.369529         27             1                 0
# 136         0  357880.159379         60             3                 0
# 137         1    1910.037592         28             0                 1
# 138         0    2572.053173         43             1                 0
# 139         0    1765.557387         29             2                 0
# 140         0    3017.782065         24             1                 1
# 141         0    1203.369529         39             1                 1
# 142         0  347947.835507         54             1                 0
# 143         0    1893.299829         48             1                 2
# 144         1    2105.382664         45             1                 1
# 145         0    1203.369529         62             1                 0
# 146         0    1302.026042         46             1                 0
# 147         0    5772.479896         47             1                 0
# 148         0    5050.292840         37             1                 0
# 149         0    2664.273168         42             1                 3
# 150         0  393711.519923         71             1                 1
# 151         0     896.462371         37             0                 1
# 152         1    3597.776388         39             1                 0
# 153         1     132.748536         20             1                 0
# 154         1    1803.930605         41             0                 2
# 155         0    1208.596179         40             1                 0
# 156         0  362366.857165         65             1                 0
# 157         0  348414.028009         38             1                 0
# 158         0   11001.589092         56             1                 0
# 159         0  371052.696813         59             1                 4
# 160         0    2063.223473         45             1                 1
# 161         1    1147.591637         39             0                 0
# 162         0    3755.843042         62             1                 0
# 163         0    7473.902957         50             1                 0
# 164         2    2357.523214         27             0                 0
# 165         2    1268.870686         32             0                 0
# 166         0     450.061342         38             1                 1
# 167         0    7219.276087         56             1                 1
# 168         0  361970.220505         67             1                 2
# 169         0  372110.892953         58             1                 1
# 170         0     182.226723         28             0                 4
# 171         0    9566.241471         60             1                 1
# 172         0    4652.167869         49             1                 0
# 173         0    9099.945305         49             1                 0
# 174         0    1203.369529         55             0                 2
# 175         2    1734.741012         38             1                 0
# 176         0  364178.254930         60             1                 0
# 177         2    2109.314691         48             1                 0
# 178         0  395728.361398         59             1                 2
# 179         0    1177.055383         43             1                 4
# 180         0      60.637328         37             1                 1
# 181         0    1203.369529         26             1                 1
# 182         1    8164.333209         49             1                 1
# 183         1     166.265037         35             0                 1
# 184         0  369682.222715         57             0                 0
# 185         0    5026.229460         32             1                 1
# 186         0     225.123689         34             1                 3
# 187         0     876.843110         46             0                 1
# 188         0      99.195947         48             1                 0
# 189         1    1203.369529         30             1                 4
# 190         0     335.522956         26             1                 1
# 191         0  336562.016432         60             1                 0
# 192         0    2573.136780         47             1                 0
# 193         0  386330.851136         60             0                 3
# 194         0      98.312162         24             1                 1
# 195         0     117.127886         51             1                 0
# 196         0    1589.781401         37             0                 0
# 197         0   12136.131381         59             0                 0
# 198         0    1403.080830         52             1                 4
# 199         1     223.547018         23             1                 2
#
#     gender  income_type  debt          purpose_category total_income_category
# 0        F    сотрудник     0  операции с недвижимостью                     B
# 1        F    сотрудник     0    операции с автомобилем                     C
# 2        M    сотрудник     0  операции с недвижимостью                     C
# 3        M    сотрудник     0     получение образования                     B
# 4        F    пенсионер     0        проведение свадьбы                     C
# 5        M    компаньон     0  операции с недвижимостью                     B
# 6        F    компаньон     0  операции с недвижимостью                     B
# 7        M    сотрудник     0     получение образования                     C
# 8        F    сотрудник     0        проведение свадьбы                     C
# 9        M    сотрудник     0  операции с недвижимостью                     C
# 10       M    компаньон     0  операции с недвижимостью                     C
# 11       F    сотрудник     0  операции с недвижимостью                     C
# 12       M    пенсионер     0        проведение свадьбы                     C
# 13       F    сотрудник     0    операции с автомобилем                     C
# 14       F    компаньон     1  операции с недвижимостью                     C
# 15       F    сотрудник     0  операции с недвижимостью                     C
# 16       F    сотрудник     0  операции с недвижимостью                     B
# 17       M    сотрудник     0  операции с недвижимостью                     C
# 18       F    пенсионер     0    операции с автомобилем                     C
# 19       F    сотрудник     0    операции с автомобилем                     B
# 20       M    сотрудник     0  операции с недвижимостью                     B
# 21       F    сотрудник     0    операции с автомобилем                     C
# 22       F    сотрудник     0    операции с автомобилем                     C
# 23       M    сотрудник     0        проведение свадьбы                     C
# 24       F    пенсионер     0  операции с недвижимостью                     B
# 25       M    пенсионер     0  операции с недвижимостью                     C
# 26       M  госслужащий     0     получение образования                     C
# 27       M    сотрудник     0  операции с недвижимостью                     B
# 28       F    сотрудник     0  операции с недвижимостью                     C
# 29       F    пенсионер     0  операции с недвижимостью                     C
# 30       F    пенсионер     0  операции с недвижимостью                     C
# 31       F    сотрудник     0  операции с недвижимостью                     B
# 32       F    сотрудник     1        проведение свадьбы                     C
# 33       F    компаньон     0  операции с недвижимостью                     C
# 34       F    сотрудник     0  операции с недвижимостью                     C
# 35       M    пенсионер     0        проведение свадьбы                     C
# 36       M    сотрудник     0    операции с автомобилем                     C
# 37       F    компаньон     0    операции с автомобилем                     C
# 38       M    сотрудник     1     получение образования                     C
# 39       F    компаньон     0     получение образования                     B
# 40       M    компаньон     0  операции с недвижимостью                     C
# 41       F  госслужащий     0    операции с автомобилем                     C
# 42       F    сотрудник     0     получение образования                     C
# 43       F    компаньон     0    операции с автомобилем                     B
# 44       F    сотрудник     0    операции с автомобилем                     C
# 45       F    сотрудник     0     получение образования                     C
# 46       F    компаньон     0    операции с автомобилем                     C
# 47       M  госслужащий     0        проведение свадьбы                     B
# 48       F    сотрудник     0  операции с недвижимостью                     C
# 49       F    сотрудник     0    операции с автомобилем                     D
# 50       F    пенсионер     0    операции с автомобилем                     C
# 51       F    сотрудник     0        проведение свадьбы                     B
# 52       F    сотрудник     0     получение образования                     C
# 53       F    компаньон     0  операции с недвижимостью                     B
# 54       F    сотрудник     0    операции с автомобилем                     C
# 55       F    пенсионер     1        проведение свадьбы                     C
# 56       F    пенсионер     0     получение образования                     C
# 57       F    сотрудник     0     получение образования                     C
# 58       M    сотрудник     0  операции с недвижимостью                     B
# 59       F    компаньон     0  операции с недвижимостью                     B
# 60       M    сотрудник     0     получение образования                     C
# 61       F    сотрудник     0  операции с недвижимостью                     C
# 62       M  госслужащий     0     получение образования                     B
# 63       F    сотрудник     0  операции с недвижимостью                     C
# 64       M    сотрудник     0    операции с автомобилем                     B
# 65       M    компаньон     0  операции с недвижимостью                     C
# 66       M    сотрудник     0     получение образования                     C
# 67       F    пенсионер     0  операции с недвижимостью                     C
# 68       M    компаньон     0  операции с недвижимостью                     B
# 69       F    сотрудник     0  операции с недвижимостью                     C
# 70       M  госслужащий     0  операции с недвижимостью                     B
# 71       F    пенсионер     0    операции с автомобилем                     D
# 72       M  госслужащий     0  операции с недвижимостью                     C
# 73       M    сотрудник     0     получение образования                     C
# 74       F    сотрудник     0  операции с недвижимостью                     C
# 75       M    сотрудник     1  операции с недвижимостью                     C
# 76       M    сотрудник     0    операции с автомобилем                     C
# 77       F    сотрудник     0    операции с автомобилем                     C
# 78       M    пенсионер     0    операции с автомобилем                     C
# 79       M    компаньон     0    операции с автомобилем                     B
# 80       F    компаньон     0    операции с автомобилем                     C
# 81       F    сотрудник     0     получение образования                     C
# 82       F    сотрудник     0  операции с недвижимостью                     C
# 83       M    сотрудник     0  операции с недвижимостью                     C
# 84       F  госслужащий     0  операции с недвижимостью                     B
# 85       M    сотрудник     0     получение образования                     C
# 86       M    пенсионер     0        проведение свадьбы                     B
# 87       F    пенсионер     0  операции с недвижимостью                     C
# 88       F    пенсионер     0        проведение свадьбы                     B
# 89       F    компаньон     0    операции с автомобилем                     D
# 90       F    сотрудник     0  операции с недвижимостью                     C
# 91       F    сотрудник     0  операции с недвижимостью                     C
# 92       F    сотрудник     0        проведение свадьбы                     C
# 93       M    сотрудник     1    операции с автомобилем                     B
# 94       F    компаньон     0        проведение свадьбы                     C
# 95       F    сотрудник     0    операции с автомобилем                     C
# 96       F    сотрудник     0  операции с недвижимостью                     C
# 97       F    сотрудник     0     получение образования                     C
# 98       F    пенсионер     0  операции с недвижимостью                     C
# 99       F    пенсионер     0    операции с автомобилем                     C
# 100      F    сотрудник     1  операции с недвижимостью                     C
# 101      F    пенсионер     0    операции с автомобилем                     C
# 102      F    компаньон     0    операции с автомобилем                     C
# 103      F    сотрудник     0  операции с недвижимостью                     C
# 104      F    пенсионер     0  операции с недвижимостью                     C
# 105      F    сотрудник     0  операции с недвижимостью                     C
# 106      F    сотрудник     0     получение образования                     C
# 107      F    компаньон     0  операции с недвижимостью                     B
# 108      F    сотрудник     0    операции с автомобилем                     C
# 109      F    сотрудник     0     получение образования                     C
# 110      M  госслужащий     0  операции с недвижимостью                     C
# 111      F    компаньон     0  операции с недвижимостью                     C
# 112      M    сотрудник     0  операции с недвижимостью                     B
# 113      F  госслужащий     0     получение образования                     C
# 114      F    сотрудник     1  операции с недвижимостью                     C
# 115      F  госслужащий     0  операции с недвижимостью                     C
# 116      M    сотрудник     0  операции с недвижимостью                     C
# 117      F    сотрудник     0    операции с автомобилем                     C
# 118      M    компаньон     0        проведение свадьбы                     C
# 119      F    пенсионер     0  операции с недвижимостью                     D
# 120      F    сотрудник     0     получение образования                     C
# 121      F    компаньон     0    операции с автомобилем                     C
# 122      F    компаньон     0    операции с автомобилем                     C
# 123      M    сотрудник     0  операции с недвижимостью                     C
# 124      F    сотрудник     1  операции с недвижимостью                     C
# 125      F    компаньон     0        проведение свадьбы                     C
# 126      M    компаньон     0  операции с недвижимостью                     B
# 127      F    сотрудник     0  операции с недвижимостью                     B
# 128      F    пенсионер     0    операции с автомобилем                     C
# 129      M    пенсионер     0    операции с автомобилем                     C
# 130      F    компаньон     0  операции с недвижимостью                     C
# 131      M    сотрудник     0     получение образования                     C
# 132      M    сотрудник     0    операции с автомобилем                     B
# 133      F    пенсионер     0     получение образования                     C
# 134      F    сотрудник     0  операции с недвижимостью                     C
# 135      M    компаньон     0  операции с недвижимостью                     C
# 136      M    пенсионер     0  операции с недвижимостью                     C
# 137      M    сотрудник     0        проведение свадьбы                     B
# 138      F  госслужащий     0  операции с недвижимостью                     C
# 139      M    компаньон     0  операции с недвижимостью                     C
# 140      F    сотрудник     0  операции с недвижимостью                     C
# 141      M    сотрудник     0        проведение свадьбы                     C
# 142      F    пенсионер     0    операции с автомобилем                     C
# 143      F    сотрудник     0  операции с недвижимостью                     C
# 144      F    сотрудник     0    операции с автомобилем                     B
# 145      M    пенсионер     0  операции с недвижимостью                     C
# 146      F    сотрудник     0  операции с недвижимостью                     C
# 147      F  госслужащий     1  операции с недвижимостью                     C
# 148      F    сотрудник     0    операции с автомобилем                     C
# 149      F    сотрудник     0  операции с недвижимостью                     C
# 150      F    пенсионер     0        проведение свадьбы                     C
# 151      F    компаньон     0        проведение свадьбы                     B
# 152      F    компаньон     0  операции с недвижимостью                     D
# 153      M    компаньон     1  операции с недвижимостью                     C
# 154      F    сотрудник     0  операции с недвижимостью                     C
# 155      F    компаньон     0     получение образования                     C
# 156      M    пенсионер     0     получение образования                     B
# 157      F    пенсионер     1    операции с автомобилем                     C
# 158      F    сотрудник     0     получение образования                     C
# 159      F    пенсионер     0    операции с автомобилем                     C
# 160      M    сотрудник     0  операции с недвижимостью                     C
# 161      F    сотрудник     0    операции с автомобилем                     C
# 162      M    сотрудник     0     получение образования                     C
# 163      M    сотрудник     0  операции с недвижимостью                     C
# 164      F    сотрудник     1    операции с автомобилем                     B
# 165      M  госслужащий     0  операции с недвижимостью                     B
# 166      M    сотрудник     0  операции с недвижимостью                     C
# 167      F  госслужащий     0        проведение свадьбы                     B
# 168      F    пенсионер     0  операции с недвижимостью                     C
# 169      F    пенсионер     0    операции с автомобилем                     C
# 170      M    сотрудник     0  операции с недвижимостью                     C
# 171      F    компаньон     0        проведение свадьбы                     B
# 172      F    сотрудник     0  операции с недвижимостью                     C
# 173      M    компаньон     0  операции с недвижимостью                     B
# 174      F    компаньон     0    операции с автомобилем                     C
# 175      F    сотрудник     0  операции с недвижимостью                     C
# 176      F    пенсионер     0     получение образования                     C
# 177      M  госслужащий     0    операции с автомобилем                     C
# 178      F    пенсионер     0    операции с автомобилем                     C
# 179      F    сотрудник     0  операции с недвижимостью                     C
# 180      F    сотрудник     0        проведение свадьбы                     B
# 181      F    компаньон     1  операции с недвижимостью                     C
# 182      F    сотрудник     0        проведение свадьбы                     C
# 183      M    компаньон     1     получение образования                     B
# 184      M    пенсионер     0  операции с недвижимостью                     C
# 185      M    сотрудник     1     получение образования                     C
# 186      F    сотрудник     0  операции с недвижимостью                     B
# 187      F    сотрудник     0     получение образования                     B
# 188      M    сотрудник     0  операции с недвижимостью                     C
# 189      F    сотрудник     0    операции с автомобилем                     C
# 190      M    компаньон     0        проведение свадьбы                     C
# 191      F    пенсионер     0     получение образования                     C
# 192      M    сотрудник     0    операции с автомобилем                     B
# 193      F    пенсионер     0    операции с автомобилем                     C
# 194      M    компаньон     0     получение образования                     C
# 195      F    сотрудник     0     получение образования                     B
# 196      F    компаньон     0  операции с недвижимостью                     C
# 197      F    сотрудник     0  операции с недвижимостью                     C
# 198      F    компаньон     0    операции с автомобилем                     C
# 199      F    сотрудник     0    операции с автомобилем                     C

# %% [markdown]
# ## Ответы на вопросы

# %% [markdown]
# ### 1. Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
kids_debt = pd.DataFrame() # создаем новый датафрейм
kids_debt['clients with debt'] = data.groupby('children')['debt'].sum() # первый столбец - задолженности у клиентов с n детей
kids_debt['all clients'] = data.groupby('children')['debt'].count() # второй - всего клиентов с n детей
kids_debt['result'] = kids_debt['clients with debt'] / kids_debt['all clients'] # отношение задолженносте к кол-ву клиентов
kids_debt['percent'] = kids_debt['result'].apply(lambda x: format(x, '.2%')) # перевод в проценты
kids = kids_debt.sort_values(by='result') # сортировка по возрастанию
print(f'Подсчёт задолженностей по количеству детей:\n {kids}') # вывод датафрейма
# Out:
# Подсчёт задолженностей по количеству детей:
#            clients with debt  all clients    result percent
# children
# 5                         0            9  0.000000   0.00%
# 0                      1063        14106  0.075358   7.54%
# 3                        27          330  0.081818   8.18%
# 1                       445         4856  0.091639   9.16%
# 2                       202         2128  0.094925   9.49%
# 4                         4           41  0.097561   9.76%

# %% [markdown]
# По последним трем значениям видно, что чем больше детей в семье, тем выше процент задолженностей среди клиентов, при этом чаще всего в срок платят клиенты без детей. Клиентов с пятью детьми слишком мало, чтобы делать выводы.

# %% [markdown]
# ### 2. Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
fam_status_debt = pd.DataFrame()
fam_status_debt['clients with debt'] = data.groupby('family_status_id')['debt'].sum()
fam_status_debt['all clients'] = data.groupby('family_status_id')['debt'].count()
fam_status_debt['result'] = fam_status_debt['clients with debt'] / fam_status_debt['all clients']
fam_status_debt['percent'] = fam_status_debt['result'].apply(lambda x: format(x, '.2%'))
fam = fam_status_debt.sort_values(by='result')
print(f'Подсчёт задолженностей по семейному статусу:\n {fam}')
# Out:
# Подсчёт задолженностей по семейному статусу:
#                    clients with debt  all clients    result percent
# family_status_id
# 2                                63          959  0.065693   6.57%
# 3                                85         1195  0.071130   7.11%
# 0                               931        12344  0.075421   7.54%
# 1                               388         4162  0.093224   9.32%
# 4                               274         2810  0.097509   9.75%

# %%
family_status_dict.value_counts() # посмотрим значение статусов
# Out:
# family_status          family_status_id
# женат / замужем        0                   12344
# гражданский брак       1                    4162
# Не женат / не замужем  4                    2810
# в разводе              3                    1195
# вдовец / вдова         2                     959
# dtype: int64

# %% [markdown]
# Меньше всего задолженностей у тех, кто состоял, либо состоит в браке. Не состоящие в браке клиенты чаще не платят в срок.

# %% [markdown]
# ### 3. Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
income_debt = pd.DataFrame()
income_debt['clients with debt'] = data.groupby('total_income_category')['debt'].sum()
income_debt['all clients'] = data.groupby('total_income_category')['debt'].count()
income_debt['result'] = income_debt['clients with debt'] / income_debt['all clients']
income_debt['percent'] = income_debt['result'].apply(lambda x: format(x, '.2%'))
income = income_debt.sort_values(by='result')
print(f'Подсчёт задолженностей по уровню дохода:\n {income}')
# Out:
# Подсчёт задолженностей по уровню дохода:
#                         clients with debt  all clients    result percent
# total_income_category
# D                                     21          350  0.060000   6.00%
# B                                    356         5041  0.070621   7.06%
# A                                      2           25  0.080000   8.00%
# C                                   1360        16032  0.084830   8.48%
# E                                      2           22  0.090909   9.09%

# %% [markdown]
# Зависимости от уровня дохода нет. По нашим данным больше всего должников с уровнем дохода меньше 30000, при этом отличие от категории "А" всего один процент. Чаще платят в срок клиенты с уровнем дохода в диапозоне 30000 - 50000, разница с минимальным значением равна 3 процентам.

# %% [markdown]
# ### 4. Как разные цели кредита влияют на его возврат в срок?

# %%
purpose_debt = pd.DataFrame()
purpose_debt['clients with debt'] = data.groupby('purpose_category')['debt'].sum()
purpose_debt['all clients'] = data.groupby('purpose_category')['debt'].count()
purpose_debt['result'] = purpose_debt['clients with debt'] / purpose_debt['all clients']
purpose_debt['percent'] = purpose_debt['result'].apply(lambda x: format(x, '.2%'))
purpose = purpose_debt.sort_values(by='result')
print(f'Подсчёт задолженностей по цели кредита:\n {purpose}')
# Out:
# Подсчёт задолженностей по цели кредита:
#                            clients with debt  all clients    result percent
# purpose_category
# операции с недвижимостью                782        10814  0.072314   7.23%
# проведение свадьбы                      186         2334  0.079692   7.97%
# получение образования                   370         4014  0.092177   9.22%
# операции с автомобилем                  403         4308  0.093547   9.35%

# %% [markdown]
# Видна зависимость от цели кредита. Клиенты, берущие кредит на недвижимость и свадьбу платят в срок чаще тех, кто хочет получить образование или приобрести автомобиль.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Выявлена зависимость оплаты кредита в срок от семейного статуса. Люди, которые не состояли в браке, вероятнее всего совершат несвоевременую оплату. При этом клиенты, состоящие в браке и без детей чаще становятся пунктуальными плательщиками.
#
# Больше всего задолженностей выявлено у клиентов, взявших кредит на автомобиль, меньше всего у тех, целью кредита которых была недвижимость.
#
# Уровень дохода влияет на платежи меньше всего.
